# %% [markdown]
# (control:examples:optimal-control:first-order:ref-tracking)=
# # First order system - Reference tracking
#
# The same as the example [first order system with time delays - reference tracking](control:examples:optimal-control:first-order-with-time-delay:ref-tracking), without time delays from the input to the output.
